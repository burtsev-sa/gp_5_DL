# %%
import pandas as pd

# %% [markdown]
# ## Описание признаков
#
# - kolesa_id - уникальный id объявления со стороны сервиса
# - kolesa_url - ссылка на объявление
# - parsed_at - дата и время получения объявления
# - brand - марка авто
# - model - модель авто
# - generation - поколение данного авто (этой марки)
# - year - год выпуска авто
# - city - город публикации объявление
# - body_type - тип кузова авто
# - fuel_type - тип топлива
# - engine_volume - объем двигателя
# - mileage - пробег в км
# - transmission - тип коробки/трансмиссии
# - drive_type - тип привода
# - steering_wheel - расположение руля
# - color - цвет авто
# - kz_registration - растаможен ли в Казахстане
# - imgs_count - количество фотографий в объявлении
# - price - цена продажи
# - img_filename - название файла с главным фото объявления
# - img_url - ссылка на на главное фото объявления
# - found_img - нашли ли фото
#
# Из них технические: kolesa_id, kolesa_url, parsed_at, img_filename, img_url, found_img
#
# Все остальные могут быть рассмотрены для решения задачи DL на табличных данных

# %%
df = pd.read_csv('fourth_df.csv')
df
# Out:
#       kolesa_id                                         kolesa_url  \
# 0     220599328  https://kolesa.kz/a/show/220599328?search_id=f...
# 1     222486528  https://kolesa.kz/a/show/222486528?search_id=f...
# 2     218695550  https://kolesa.kz/a/show/218695550?search_id=f...
# 3     220471159  https://kolesa.kz/a/show/220471159?search_id=f...
# 4     214781208  https://kolesa.kz/a/show/214781208?search_id=f...
# ...         ...                                                ...
# 5391  222704181  https://kolesa.kz/a/show/222704181?search_id=6...
# 5392  220000872  https://kolesa.kz/a/show/220000872?search_id=6...
# 5393  222682662  https://kolesa.kz/a/show/222682662?search_id=6...
# 5394  222542135  https://kolesa.kz/a/show/222542135?search_id=6...
# 5395  220019907  https://kolesa.kz/a/show/220019907?search_id=6...
#
#                              parsed_at      brand     model  \
# 0     2026-06-11 12:11:47.553405+03:00  Chevrolet    Cobalt
# 1     2026-06-11 12:11:59.858484+03:00  Chevrolet     Monza
# 2     2026-06-11 12:12:12.664183+03:00  Chevrolet   Captiva
# 3     2026-06-11 12:12:28.093064+03:00  Chevrolet     Cruze
# 4     2026-06-11 12:12:44.777117+03:00  Chevrolet      Aveo
# ...                                ...        ...       ...
# 5391  2026-06-11 01:33:57.011643+03:00    Hyundai  Grandeur
# 5392  2026-06-11 01:34:13.055741+03:00    Hyundai    Sonata
# 5393  2026-06-11 01:34:37.636103+03:00    Hyundai       i30
# 5394  2026-06-11 01:34:52.986032+03:00    Hyundai   Elantra
# 5395  2026-06-11 01:35:29.695414+03:00    Hyundai    Tucson
#
#                                              generation  year  \
# 0                             2011 - н.в. 2 поколение\n  2021
# 1                  2022 - н.в. 2 поколение рестайлинг\n  2023
# 2                             2018 - н.в. 2 поколение\n  2021
# 3                         2012 - 2015 J300 рестайлинг\n  2013
# 4             2006 - 2012 T250 рестайлинг (T250/T255)\n  2007
# ...                                                 ...   ...
# 5391                                   2011 - 2016 HG\n  2011
# 5392                    2019 - н.в. 8 поколение (DN8)\n  2022
# 5393          2020 - н.в. 3 поколение рестайлинг (PD)\n  2023
# 5394      2018 - 2020 6 поколение рестайлинг (AD/ADA)\n  2018
# 5395      2018 - 2021 3 поколение рестайлинг (TL/TLE)\n  2018
#
#                                                    city          body_type  \
# 0     \n                                    Астана, ...            Седан\n
# 1     \n                                    Астана, ...            Седан\n
# 2     \n                                    Алматы, ...      Внедорожник\n
# 3     \n                                    Алматы, ...          Хэтчбек\n
# 4     \n                                    Астана, ...            Седан\n
# ...                                                 ...                ...
# 5391  \n                                    Шымкент,...            Седан\n
# 5392  \n                                    Атырау, ...            Седан\n
# 5393  \n                                    Шымкент,...        Универсал\n
# 5394  \n                                    Уральск,...            Седан\n
# 5395  \n                                    Актобе, ...        Кроссовер\n
#
#      fuel_type  ...   transmission             drive_type steering_wheel  \
# 0       бензин  ...      Автомат\n      Передний привод\n        Слева\n
# 1       бензин  ...        Робот\n      Передний привод\n        Слева\n
# 2       бензин  ...      Автомат\n      Передний привод\n        Слева\n
# 3       бензин  ...      Автомат\n      Передний привод\n        Слева\n
# 4       бензин  ...      Автомат\n      Передний привод\n        Слева\n
# ...        ...  ...            ...                    ...            ...
# 5391    бензин  ...      Автомат\n      Передний привод\n        Слева\n
# 5392    бензин  ...      Автомат\n      Передний привод\n        Слева\n
# 5393    бензин  ...      Автомат\n      Передний привод\n        Слева\n
# 5394    бензин  ...      Автомат\n      Передний привод\n        Слева\n
# 5395    бензин  ...      Автомат\n      Передний привод\n        Слева\n
#
#                                                   color kz_registration  \
# 0     \n                                        черн...            Да\n
# 1     \n                                        серы...            Да\n
# 2     \n                                        серы...            Да\n
# 3     \n                                        сере...            Да\n
# 4                                                   NaN            Да\n
# ...                                                 ...             ...
# 5391  \n                                        белы...            Да\n
# 5392                                                NaN            Да\n
# 5393  \n                                        белы...            Да\n
# 5394                                                NaN            Да\n
# 5395                                                NaN            Да\n
#
#      imgs_count     price    img_filename  \
# 0            25   4490000  220599328.webp
# 1             6   6400000  222486528.webp
# 2            27   7150000  218695550.webp
# 3             8   4400000  220471159.webp
# 4            10   2450000  214781208.webp
# ...         ...       ...             ...
# 5391         24   8300000  222704181.webp
# 5392         11  12500000  220000872.webp
# 5393         10   9000000  222682662.webp
# 5394         19   6200000  222542135.webp
# 5395         21   9900000  220019907.webp
#
#                                                 img_url found_img
# 0     https://kolesa-photos.kcdn.online/webp/de/de4f...      True
# 1     https://kolesa-photos.kcdn.online/webp/c1/c19d...      True
# 2     https://kolesa-photos.kcdn.online/webp/55/5518...      True
# 3     https://kolesa-photos.kcdn.online/webp/bb/bb26...      True
# 4     https://kolesa-photos.kcdn.online/webp/bb/bb06...      True
# ...                                                 ...       ...
# 5391  https://kolesa-photos.kcdn.online/webp/d6/d6c9...      True
# 5392  https://kolesa-photos.kcdn.online/webp/22/2242...      True
# 5393  https://kolesa-photos.kcdn.online/webp/7b/7b0f...      True
# 5394  https://kolesa-photos.kcdn.online/webp/9e/9ef9...      True
# 5395  https://kolesa-photos.kcdn.online/webp/0c/0c61...      True
#
# [5396 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5396 entries, 0 to 5395
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   kolesa_id        5396 non-null   int64
#  1   kolesa_url       5396 non-null   str
#  2   parsed_at        5396 non-null   str
#  3   brand            5396 non-null   str
#  4   model            5396 non-null   str
#  5   generation       5390 non-null   str
#  6   year             5396 non-null   int64
#  7   city             5396 non-null   str
#  8   body_type        5396 non-null   str
#  9   fuel_type        5396 non-null   str
#  10  engine_volume    5396 non-null   float64
#  11  mileage          5396 non-null   int64
#  12  transmission     5396 non-null   str
#  13  drive_type       5396 non-null   str
#  14  steering_wheel   5396 non-null   str
#  15  color            3959 non-null   str
#  16  kz_registration  5396 non-null   str
#  17  imgs_count       5396 non-null   int64
#  18  price            5396 non-null   int64
#  19  img_filename     5376 non-null   str
#  20  img_url          5376 non-null   str
#  21  found_img        5396 non-null   bool
# dtypes: bool(1), float64(1), int64(5), str(15)
# memory usage: 890.7 KB

# %% [markdown]
# ## Подгтовим данные для дальнейшей работы

# %% [markdown]
# Общая проверка на пропуски

# %%
df.isna().sum()
# Out:
# kolesa_id             0
# kolesa_url            0
# parsed_at             0
# brand                 0
# model                 0
# generation            6
# year                  0
# city                  0
# body_type             0
# fuel_type             0
# engine_volume         0
# mileage               0
# transmission          0
# drive_type            0
# steering_wheel        0
# color              1437
# kz_registration       0
# imgs_count            0
# price                 0
# img_filename         20
# img_url              20
# found_img             0
# dtype: int64

# %% [markdown]
# Основная проблема - пропуски в color. Это было обнаружено еще в ходе парсинга. Заполним их значением
#
# Пропуски в img_filename и img_url мы будем отдельно обрабатывать позже

# %%
df['color'] = df['color'].fillna('unknown')

# %% [markdown]
# ### City, body_type, transmission, drive_type, steering_wheel, color, kz_registration

# %%
df[['city', 'body_type', 'transmission', 'drive_type', 'steering_wheel', 'color', 'kz_registration']]
# Out:
#                                                    city          body_type  \
# 0     \n                                    Астана, ...            Седан\n
# 1     \n                                    Астана, ...            Седан\n
# 2     \n                                    Алматы, ...      Внедорожник\n
# 3     \n                                    Алматы, ...          Хэтчбек\n
# 4     \n                                    Астана, ...            Седан\n
# ...                                                 ...                ...
# 5391  \n                                    Шымкент,...            Седан\n
# 5392  \n                                    Атырау, ...            Седан\n
# 5393  \n                                    Шымкент,...        Универсал\n
# 5394  \n                                    Уральск,...            Седан\n
# 5395  \n                                    Актобе, ...        Кроссовер\n
#
#        transmission             drive_type steering_wheel  \
# 0         Автомат\n      Передний привод\n        Слева\n
# 1           Робот\n      Передний привод\n        Слева\n
# 2         Автомат\n      Передний привод\n        Слева\n
# 3         Автомат\n      Передний привод\n        Слева\n
# 4         Автомат\n      Передний привод\n        Слева\n
# ...             ...                    ...            ...
# 5391      Автомат\n      Передний привод\n        Слева\n
# 5392      Автомат\n      Передний привод\n        Слева\n
# 5393      Автомат\n      Передний привод\n        Слева\n
# 5394      Автомат\n      Передний привод\n        Слева\n
# 5395      Автомат\n      Передний привод\n        Слева\n
#
#                                                   color kz_registration
# 0     \n                                        черн...            Да\n
# 1     \n                                        серы...            Да\n
# 2     \n                                        серы...            Да\n
# 3     \n                                        сере...            Да\n
# 4                                               unknown            Да\n
# ...                                                 ...             ...
# 5391  \n                                        белы...            Да\n
# 5392                                            unknown            Да\n
# 5393  \n                                        белы...            Да\n
# 5394                                            unknown            Да\n
# 5395                                            unknown            Да\n
#
# [5396 rows x 7 columns]

# %% [markdown]
# Все это признаки, содержащие текст
#
# Заметим, что у нас не убраны символы переноса строк \n и, возможно, лишние пробелы
#
# Уберем это у всех этих признаков

# %%
df['city'] = df['city'].apply(lambda x: x.replace('\n', '').strip())
df['body_type'] = df['body_type'].apply(lambda x: x.replace('\n', '').strip())
df['transmission'] = df['transmission'].apply(lambda x: x.replace('\n', '').strip())
df['drive_type'] = df['drive_type'].apply(lambda x: x.replace('\n', '').strip())
df['steering_wheel'] = df['steering_wheel'].apply(lambda x: x.replace('\n', '').strip())
df['color'] = df['color'].apply(lambda x: x.replace('\n', '').strip())
df['kz_registration'] = df['kz_registration'].apply(lambda x: x.replace('\n', '').strip())

# %%
df[['city', 'body_type', 'transmission', 'drive_type', 'steering_wheel', 'color', 'kz_registration']]
# Out:
#                                         city    body_type transmission  \
# 0                Астана, Акмолинская область        Седан      Автомат
# 1                Астана, Акмолинская область        Седан        Робот
# 2                Алматы, Алматинская область  Внедорожник      Автомат
# 3                Алматы, Алматинская область      Хэтчбек      Автомат
# 4                Астана, Акмолинская область        Седан      Автомат
# ...                                      ...          ...          ...
# 5391          Шымкент, Туркестанская область        Седан      Автомат
# 5392              Атырау, Атырауская область        Седан      Автомат
# 5393          Шымкент, Туркестанская область    Универсал      Автомат
# 5394  Уральск, Западно-Казахстанская область        Седан      Автомат
# 5395             Актобе, Актюбинская область    Кроссовер      Автомат
#
#            drive_type steering_wheel           color kz_registration
# 0     Передний привод          Слева          черный              Да
# 1     Передний привод          Слева  серый металлик              Да
# 2     Передний привод          Слева           серый              Да
# 3     Передний привод          Слева     серебристый              Да
# 4     Передний привод          Слева         unknown              Да
# ...               ...            ...             ...             ...
# 5391  Передний привод          Слева           белый              Да
# 5392  Передний привод          Слева         unknown              Да
# 5393  Передний привод          Слева  белый металлик              Да
# 5394  Передний привод          Слева         unknown              Да
# 5395  Передний привод          Слева         unknown              Да
#
# [5396 rows x 7 columns]

# %%
df.to_csv('clean_df.csv', index=False)

# %%
df_table = df.copy()
df_table = df_table.drop(columns=['kolesa_id', 'kolesa_url', 'parsed_at', 'img_filename', 'img_url', 'found_img'])
df_table.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5396 entries, 0 to 5395
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            5396 non-null   str
#  1   model            5396 non-null   str
#  2   generation       5390 non-null   str
#  3   year             5396 non-null   int64
#  4   city             5396 non-null   str
#  5   body_type        5396 non-null   str
#  6   fuel_type        5396 non-null   str
#  7   engine_volume    5396 non-null   float64
#  8   mileage          5396 non-null   int64
#  9   transmission     5396 non-null   str
#  10  drive_type       5396 non-null   str
#  11  steering_wheel   5396 non-null   str
#  12  color            5396 non-null   str
#  13  kz_registration  5396 non-null   str
#  14  imgs_count       5396 non-null   int64
#  15  price            5396 non-null   int64
# dtypes: float64(1), int64(4), str(11)
# memory usage: 674.6 KB
