# %%
import pandas as pd
import os

# %% [markdown]
# Получим имена всех собранных датасетов

# %%
# https://sky.pro/wiki/media/rabota-s-fajlami-v-python-kak-poluchit-spisok-vseh-fajlov-v-direktorii/
kolesa_datasets = os.listdir('data/raw')

# %%
df_parsed = None
for filename in kolesa_datasets:
    if df_parsed is None:
        df_parsed = pd.read_csv('data/raw/' + filename)
        continue

    df_temp = pd.read_csv('data/raw/' + filename)
    df_parsed = pd.concat([df_parsed, df_temp], axis=0)

# %%
df_parsed
# Out:
#      kolesa_id                                         kolesa_url  \
# 0    221971452  https://kolesa.kz/a/show/221971452?search_id=4...
# 1    184557634  https://kolesa.kz/a/show/184557634?search_id=4...
# 2    222310850  https://kolesa.kz/a/show/222310850?search_id=4...
# 3    206731143  https://kolesa.kz/a/show/206731143?search_id=4...
# 4    221564600  https://kolesa.kz/a/show/221564600?search_id=4...
# ..         ...                                                ...
# 110  221964394  https://kolesa.kz/a/show/221964394?search_id=3...
# 111  209668596  https://kolesa.kz/a/show/209668596?search_id=3...
# 112  222050007  https://kolesa.kz/a/show/222050007?search_id=3...
# 113  218447227  https://kolesa.kz/a/show/218447227?search_id=3...
# 114  221275637  https://kolesa.kz/a/show/221275637?search_id=3...
#
#                             parsed_at brand     model  \
# 0    2026-06-08 10:31:39.616294+03:00   Kia        K5
# 1    2026-06-08 10:31:55.104766+03:00   Kia   Sorento
# 2    2026-06-08 10:32:07.399668+03:00   Kia        K7
# 3    2026-06-08 10:32:37.197220+03:00   Kia      Soul
# 4    2026-06-08 10:33:04.907473+03:00   Kia      Soul
# ..                                ...   ...       ...
# 110  2026-06-06 20:48:48.510058+03:00   Kia      Soul
# 111  2026-06-06 20:49:03.080793+03:00   Kia  Sportage
# 112  2026-06-06 20:49:19.219851+03:00   Kia   Cadenza
# 113  2026-06-06 20:49:31.995428+03:00   Kia   Sorento
# 114  2026-06-06 20:49:46.638349+03:00   Kia      Soul
#
#                                         generation  year  \
# 0             2023 - н.в. 3 поколение рестайлинг\n  2025
# 1        2017 - 2020 3 поколение рестайлинг (UM)\n  2020
# 2             2012 - 2015 1 поколение рестайлинг\n  2014
# 3                   2013 - 2016 2 поколение (PS)\n  2014
# 4        2011 - 2014 1 поколение рестайлинг (AM)\n  2013
# ..                                             ...   ...
# 110                                            NaN  2022
# 111           2018 - н.в. 4 поколение рестайлинг\n  2021
# 112                      2009 - 2013 1 поколение\n  2013
# 113           2020 - н.в. 4 поколение (MQ4/MQ4A)\n  2023
# 114                 2013 - 2016 2 поколение (PS)\n  2014
#
#                                                   city        body_type  \
# 0    \n                                    Астана, ...          Седан\n
# 1    \n                                    Астана, ...      Кроссовер\n
# 2    \n                                    Алматы, ...          Седан\n
# 3    \n                                    Караганд...        Хэтчбек\n
# 4    \n                                    Панфилов...        Хэтчбек\n
# ..                                                 ...              ...
# 110  \n                                    Астана, ...        Хэтчбек\n
# 111  \n                                    Алматы, ...      Кроссовер\n
# 112  \n                                    Астана, ...          Седан\n
# 113  \n                                    Алматы, ...      Кроссовер\n
# 114  \n                                    Алматы, ...        Хэтчбек\n
#
#     fuel_type  ...   transmission             drive_type steering_wheel  \
# 0      бензин  ...      Автомат\n      Передний привод\n        Слева\n
# 1      бензин  ...      Автомат\n        Полный привод\n        Слева\n
# 2      бензин  ...      Автомат\n      Передний привод\n        Слева\n
# 3      бензин  ...      Автомат\n      Передний привод\n        Слева\n
# 4      бензин  ...      Автомат\n      Передний привод\n        Слева\n
# ..        ...  ...            ...                    ...            ...
# 110    бензин  ...      Автомат\n      Передний привод\n        Слева\n
# 111    бензин  ...      Автомат\n        Полный привод\n        Слева\n
# 112    бензин  ...      Автомат\n      Передний привод\n        Слева\n
# 113    бензин  ...      Автомат\n        Полный привод\n        Слева\n
# 114    бензин  ...      Автомат\n      Передний привод\n        Слева\n
#
#                                                  color kz_registration  \
# 0    \n                                        черн...            Да\n
# 1    \n                                        кори...            Да\n
# 2    \n                                        черн...            Да\n
# 3    \n                                        крас...            Да\n
# 4    \n                                        беже...            Да\n
# ..                                                 ...             ...
# 110  \n                                        черн...            Да\n
# 111  \n                                        белы...            Да\n
# 112  \n                                        белы...            Да\n
# 113  \n                                        черн...            Да\n
# 114  \n                                        сере...            Да\n
#
#     imgs_count     price    img_filename  \
# 0           13  14100000  221971452.webp
# 1           11  13500000  184557634.webp
# 2           25   9500000  222310850.webp
# 3           15   6300000  206731143.webp
# 4           13   5600000  221564600.webp
# ..         ...       ...             ...
# 110         22   8690000  221964394.webp
# 111         26  11500000  209668596.webp
# 112         28   5390000  222050007.webp
# 113         14  15000000  218447227.webp
# 114          9   6350000  221275637.webp
#
#                                                img_url found_img
# 0    https://kolesa-photos.kcdn.online/webp/72/724f...      True
# 1    https://kolesa-photos.kcdn.online/webp/3f/3f1b...      True
# 2    https://kolesa-photos.kcdn.online/webp/13/136a...      True
# 3    https://kolesa-photos.kcdn.online/webp/95/95f3...      True
# 4    https://kolesa-photos.kcdn.online/webp/d4/d458...      True
# ..                                                 ...       ...
# 110  https://kolesa-photos.kcdn.online/webp/f6/f67c...      True
# 111  https://kolesa-photos.kcdn.online/webp/f0/f020...      True
# 112  https://kolesa-photos.kcdn.online/webp/d6/d659...      True
# 113  https://kolesa-photos.kcdn.online/webp/4b/4b8e...      True
# 114  https://kolesa-photos.kcdn.online/webp/34/342a...      True
#
# [4521 rows x 22 columns]

# %%
df_parsed = df_parsed.drop_duplicates('kolesa_id')

# %%
df_parsed.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3717 entries, 0 to 113
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   kolesa_id        3717 non-null   int64
#  1   kolesa_url       3717 non-null   str
#  2   parsed_at        3717 non-null   str
#  3   brand            3717 non-null   str
#  4   model            3717 non-null   str
#  5   generation       3712 non-null   str
#  6   year             3717 non-null   int64
#  7   city             3717 non-null   str
#  8   body_type        3717 non-null   str
#  9   fuel_type        3717 non-null   str
#  10  engine_volume    3717 non-null   float64
#  11  mileage          3717 non-null   int64
#  12  transmission     3717 non-null   str
#  13  drive_type       3717 non-null   str
#  14  steering_wheel   3717 non-null   str
#  15  color            2751 non-null   str
#  16  kz_registration  3717 non-null   str
#  17  imgs_count       3717 non-null   int64
#  18  price            3717 non-null   int64
#  19  img_filename     3706 non-null   str
#  20  img_url          3706 non-null   str
#  21  found_img        3717 non-null   bool
# dtypes: bool(1), float64(1), int64(5), str(15)
# memory usage: 642.5 KB

# %%
df_parsed.to_csv('third_df.csv', index=False)

# %%
df_parsed.shape
# Out:
# (3717, 22)

# %%
df_parsed['brand'].value_counts()
# Out:
# brand
# Toyota           591
# Kia              522
# Lexus            496
# Audi             460
# Mercedes-Benz    448
# BMW              420
# Hyundai          390
# Chevrolet        390
# Name: count, dtype: int64

# %%
df_parsed['body_type'].value_counts()
# Out:
# body_type
# Седан\n           2027
# Кроссовер\n        902
# Внедорожник\n      380
# Хэтчбек\n          114
# Минивэн\n           99
# Универсал\n         86
# Купе\n              30
# Лифтбек\n           20
# Фургон\n            20
# Пикап\n             16
# Микровэн\n           9
# Микроавтобус\n       7
# Кабриолет\n          5
# Родстер\n            2
# Name: count, dtype: int64
